# %% [markdown]
# <a href="https://colab.research.google.com/github/noediem/cek/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Visualisasi Tampilan Halaman Produk terhadap Keinginan Pengguna Menambahkan Barang ke Keranjang

# %% [markdown]
# Import Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Membaca Dataset

# %%
df=pd.read_excel('ecommerce.xlsx')
df.head()
# Out:
#    product_views  cart_additions  ad_clicks  discount_rate  user_rating  \
# 0          476.0           104.0        8.0       0.469485     3.938120
# 1          263.0            30.0       32.0       0.332805     1.202047
# 2          673.0            69.0      199.0       0.132137     2.998779
# 3          442.0            41.0      293.0       0.219348     4.846158
# 4          317.0           156.0      220.0            NaN     2.138555
#
#    time_on_site device_type   purchases
# 0     12.305345      Mobile  124.059080
# 1     19.725696     Desktop   50.280492
# 2     13.281701     Desktop  126.721650
# 3     14.728468     Desktop  140.984766
# 4      2.032118      Tablet  158.673366

# %% [markdown]
# Melihat Struktur Data

# %%
df.shape #Jumlah Baris dan Kolom
# Out:
# (1000, 8)

# %%
df.info() #Tipe Data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_views   973 non-null    float64
#  1   cart_additions  960 non-null    float64
#  2   ad_clicks       969 non-null    float64
#  3   discount_rate   973 non-null    float64
#  4   user_rating     969 non-null    float64
#  5   time_on_site    967 non-null    float64
#  6   device_type     972 non-null    object
#  7   purchases       965 non-null    float64
# dtypes: float64(7), object(1)
# memory usage: 62.6+ KB

# %%
df.columns #Nama nama Kolom
# Out:
# Index(['product_views', 'cart_additions', 'ad_clicks', 'discount_rate',
#        'user_rating', 'time_on_site', 'device_type', 'purchases'],
#       dtype='object')

# %% [markdown]
# Statistik Deskriptif

# %%
df.describe()
# Out:
#        product_views  cart_additions    ad_clicks  discount_rate  user_rating  \
# count     973.000000      960.000000   969.000000     973.000000   969.000000
# mean      561.817164      108.887303   157.658032       0.260271     2.992306
# std       344.613674       66.443119   105.712774       0.174874     1.424730
# min        50.000000       10.000000     5.000000       0.000214     1.000685
# 25%       307.000000       60.000000    77.000000       0.131998     1.956601
# 50%       562.000000      105.000000   154.000000       0.255889     2.884753
# 75%       798.000000      155.250000   232.000000       0.379237     3.936347
# max      3355.420177      646.162188  1013.726581       1.677047    14.525710
#
#        time_on_site   purchases
# count    967.000000  965.000000
# mean      10.555324  141.328806
# std        6.029412   44.162571
# min        1.000000   44.661202
# 25%        6.846868  114.734281
# 50%       10.176409  138.213613
# 75%       13.532057  165.943369
# ...

# %% [markdown]
# Cek Missing Value

# %%
df.isnull().sum()
# Out:
# product_views     27
# cart_additions    40
# ad_clicks         31
# discount_rate     27
# user_rating       31
# time_on_site      33
# device_type       28
# purchases         35
# dtype: int64

# %% [markdown]
# Histogram
